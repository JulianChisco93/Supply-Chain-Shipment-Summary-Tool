# %% [markdown]
# # File to test functions related to data loader

# %% [markdown]
# #### 1. Import libraries

# %%
import sys
from pathlib import Path

project_root = Path("..").resolve()
sys.path.append(str(project_root))

import pandas as pd
import matplotlib.pyplot as plt

from pathlib import Path

# %%
from src.data_loader import load_raw_data

# %%
df_RowData = load_raw_data("../data/supply_delivery_history.csv")
df_RowData.head()
# Out:
#    ID        Country  Fulfill Via Shipment Mode Scheduled Delivery Date  \
# 0   1  Côte d'Ivoire  Direct Drop           Air                2-Jun-06
# 1   3        Vietnam  Direct Drop           Air               14-Nov-06
# 2   4  Côte d'Ivoire  Direct Drop           Air               27-Aug-06
# 3  15        Vietnam  Direct Drop           Air                1-Sep-06
# 4  16        Vietnam  Direct Drop           Air               11-Aug-06
#
#   Delivered to Client Date Delivery Recorded Date Product Group  \
# 0                 2-Jun-06               2-Jun-06          HRDT
# 1                14-Nov-06              14-Nov-06           ARV
# 2                27-Aug-06              27-Aug-06          HRDT
# 3                 1-Sep-06               1-Sep-06           ARV
# 4                11-Aug-06              11-Aug-06           ARV
#
#   Sub Classification                                             Vendor  ...  \
# ...

# %%
from src.data_loader import load_clean_data

# %%
df_CleanData = load_clean_data("../data/supply_delivery_history_clean.csv")
df_CleanData.head()
# Out:
#    ID        Country  Fulfill Via Shipment Mode Scheduled Delivery Date  \
# 0   1  Côte d'Ivoire  Direct Drop           Air                2-Jun-06
# 1   3        Vietnam  Direct Drop           Air               14-Nov-06
# 2   4  Côte d'Ivoire  Direct Drop           Air               27-Aug-06
# 3  15        Vietnam  Direct Drop           Air                1-Sep-06
# 4  16        Vietnam  Direct Drop           Air               11-Aug-06
#
#   Delivered to Client Date Delivery Recorded Date Product Group  \
# 0                 2-Jun-06               2-Jun-06          HRDT
# 1                14-Nov-06              14-Nov-06           ARV
# 2                27-Aug-06              27-Aug-06          HRDT
# 3                 1-Sep-06               1-Sep-06           ARV
# 4                11-Aug-06              11-Aug-06           ARV
#
#   Sub Classification                                             Vendor  ...  \
# ...

# %% [markdown]
# #### Test functionality with Absolute Path for files

# %%
import src.data_loader as dl

# %%
project_root = Path("..").resolve()
sys.path.append(str(project_root))
project_root
# Out:
# WindowsPath('E:/jcuenca/OneDrive - GUSCanada/4toTerm/01_AgileSoftware/02_Assignment2/supply/Supply-Chain-Shipment-Summary-Tool')

# %%
print(dl.PROJECT_ROOT)
print(dl.CLEAN_DATA_PATH)
print(dl.CLEAN_DATA_PATH.exists())
# Out:
# E:\jcuenca\OneDrive - GUSCanada\4toTerm\01_AgileSoftware\02_Assignment2\supply\Supply-Chain-Shipment-Summary-Tool
# E:\jcuenca\OneDrive - GUSCanada\4toTerm\01_AgileSoftware\02_Assignment2\supply\Supply-Chain-Shipment-Summary-Tool\data\supply_delivery_history_clean.csv
# True

# %%
df_RowData2 = load_raw_data()
df_RowData2.head()
# Out:
#    ID        Country  Fulfill Via Shipment Mode Scheduled Delivery Date  \
# 0   1  Côte d'Ivoire  Direct Drop           Air                2-Jun-06
# 1   3        Vietnam  Direct Drop           Air               14-Nov-06
# 2   4  Côte d'Ivoire  Direct Drop           Air               27-Aug-06
# 3  15        Vietnam  Direct Drop           Air                1-Sep-06
# 4  16        Vietnam  Direct Drop           Air               11-Aug-06
#
#   Delivered to Client Date Delivery Recorded Date Product Group  \
# 0                 2-Jun-06               2-Jun-06          HRDT
# 1                14-Nov-06              14-Nov-06           ARV
# 2                27-Aug-06              27-Aug-06          HRDT
# 3                 1-Sep-06               1-Sep-06           ARV
# 4                11-Aug-06              11-Aug-06           ARV
#
#   Sub Classification                                             Vendor  ...  \
# ...

# %%
df_CleanData2 = load_clean_data("../data/supply_delivery_history_clean.csv")
df_CleanData2.head()
# Out:
#    ID        Country  Fulfill Via Shipment Mode Scheduled Delivery Date  \
# 0   1  Côte d'Ivoire  Direct Drop           Air                2-Jun-06
# 1   3        Vietnam  Direct Drop           Air               14-Nov-06
# 2   4  Côte d'Ivoire  Direct Drop           Air               27-Aug-06
# 3  15        Vietnam  Direct Drop           Air                1-Sep-06
# 4  16        Vietnam  Direct Drop           Air               11-Aug-06
#
#   Delivered to Client Date Delivery Recorded Date Product Group  \
# 0                 2-Jun-06               2-Jun-06          HRDT
# 1                14-Nov-06              14-Nov-06           ARV
# 2                27-Aug-06              27-Aug-06          HRDT
# 3                 1-Sep-06               1-Sep-06           ARV
# 4                11-Aug-06              11-Aug-06           ARV
#
#   Sub Classification                                             Vendor  ...  \
# ...
